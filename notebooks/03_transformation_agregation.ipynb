# %% [markdown]
# # 03 — Transformation et agrégation
# Objectif : synthétiser le montant des pourboires par jour sans modification en chaîne.

# %%
from pathlib import Path

import pandas as pd

from src.analysis import summarize_by_category

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
tips = pd.read_csv(PROJECT_ROOT / "data" / "raw" / "tips.csv")

# %% [markdown]
# ## Contrôle qualité

# %%
tips[["day", "tip"]].isna().sum()

# %% [markdown]
# ## Agrégation

# %%
summary = summarize_by_category(tips, "day", "tip")
summary.sort_values("moyenne", ascending=False)

# %% [markdown]
# ## Conclusion
# L'agrégation met en regard volume d'observations, moyenne et médiane afin d'éviter une lecture fondée sur un seul indicateur.
