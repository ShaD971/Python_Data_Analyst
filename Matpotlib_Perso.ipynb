# %% [markdown]
# Matplotlib

# %% [markdown]
# 1er graphique simple + préparer sont jeu de données

# %%
import pandas as pd 
donnees=pd.read_csv("csv/athlete_events.csv",index_col=[1])
donnees.isna().sum()
# Out:
# ID             0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
donnees=pd.read_csv("csv/athlete_events.csv",index_col=[1])
donnees['Medal']=donnees['Medal'].fillna("None")

# %% [markdown]
# On créé 2 jeux de données pour les utiliser selon se que l'on veux etudier.
# On supprime les valeur manuantes page 249

# %%
donnees=pd.read_csv("csv/athlete_events.csv",index_col=[1])
donnees['Medal']=donnees['Medal'].fillna("None")
donnees_NaN_supprimes = donnees.dropna(how="any")
donnees[['Age','Height','Weight']]=donnees[['Age','Height','Weight']].fillna(donnees[['Age','Height','Weight']].mean())
donnees_NaN_remplaces=donnees.drop_duplicates()
donnees_NaN_supprimes=donnees_NaN_supprimes.drop_duplicates()
print("Taleau avec NaN remplacés")
print(donnees_NaN_remplaces.shape)
print("Tableau avec suppression des lignes contenant des NaN")
print(donnees_NaN_supprimes.shape)
# Out:
# Taleau avec NaN remplacés
# (269731, 14)
# Tableau avec suppression des lignes contenant des NaN
# (206152, 14)

# %% [markdown]
# Créer un nuage de points p 250

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.subplot(111)
plt.plot(donnees_NaN_supprimes["Height"],donnees_NaN_supprimes["Weight"])
plt.show()
